# %%
import numpy as np  # for numerical analysis
import pandas as pd # for data manipulation
import matplotlib.pyplot as plt   # Data visualization
import seaborn as sns  # Data visualization

# machine learning library
# from sklearn import dataset
#-----Preprocessing liabrary---
from sklearn.preprocessing import StandardScaler # for normalization of data x-xmean etc
from sklearn.preprocessing import LabelEncoder # when your label is in categorical form

#-----Feature selection and Dimensionality Reduction ----
from sklearn.feature_selection import RFE
from sklearn.decomposition import PCA
from sklearn.feature_extraction import *

#-----ML libraries ----
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression


from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor


from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

from sklearn.naive_bayes import GaussianNB

#-----Parameter tuning ------
from sklearn.model_selection import GridSearchCV


#---Evaluation Metrics-----
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn import metrics
# from sklearn.metrics impport precision_score, recall_score, f1_score, 
from sklearn.metrics import classification_report  # result of model that how the model performing

#-----Pipelining--------
from sklearn.pipeline import Pipeline

# %%
from sklearn import datasets

# %%
d = datasets.load_wine

# %%
d
# Out:
# <function sklearn.datasets._base.load_wine(*, return_X_y=False, as_frame=False)>

# %%
dir(d)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
d.feature_names
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9144\2523375867.py in <module>
# ----> 1 d.feature_names
#
# AttributeError: 'function' object has no attribute 'feature_names'

# %%
dataset = pd.read_csv('C:\\Users\\Lenovo\\Desktop\\cdac\\AA\\wine.csv')

# %%
dataset.shape
# Out:
# (25, 7)

# %%
dataset.info
# Out:
# <bound method DataFrame.info of     Year   Price  WinterRain     AGST  HarvestRain  Age  FrancePop
# 0   1952  7.4950         600  17.1167          160   31  43183.569
# 1   1953  8.0393         690  16.7333           80   30  43495.030
# 2   1955  7.6858         502  17.1500          130   28  44217.857
# 3   1957  6.9845         420  16.1333          110   26  45152.252
# 4   1958  6.7772         582  16.4167          187   25  45653.805
# 5   1959  8.0757         485  17.4833          187   24  46128.638
# 6   1960  6.5188         763  16.4167          290   23  46583.995
# 7   1961  8.4937         830  17.3333           38   22  47128.005
# 8   1962  7.3880         697  16.3000           52   21  48088.673
# 9   1963  6.7127         608  15.7167          155   20  48798.990
# 10  1964  7.3094         402  17.2667           96   19  49356.943
# 11  1965  6.2518         602  15.3667          267   18  49801.821
# 12  1966  7.7443         819  16.5333           86   17  50254.966
# ...

# %%
dataset.head()
# Out:
#    Year   Price  WinterRain     AGST  HarvestRain  Age  FrancePop
# 0  1952  7.4950         600  17.1167          160   31  43183.569
# 1  1953  8.0393         690  16.7333           80   30  43495.030
# 2  1955  7.6858         502  17.1500          130   28  44217.857
# 3  1957  6.9845         420  16.1333          110   26  45152.252
# 4  1958  6.7772         582  16.4167          187   25  45653.805

# %%
#diff colom has value in diff range so we have to normalize this

dataset.describe()
# so here no any null value thus dont need to normalize
# Out:
#               Year      Price  WinterRain       AGST  HarvestRain        Age  \
# count    25.000000  25.000000   25.000000  25.000000    25.000000  25.000000
# mean   1965.800000   7.067224  605.280000  16.509336   148.560000  17.200000
# std       7.691987   0.650341  132.277965   0.675397    74.419464   7.691987
# min    1952.000000   6.204900  376.000000  14.983300    38.000000   5.000000
# 25%    1960.000000   6.518800  536.000000  16.200000    89.000000  11.000000
# 50%    1966.000000   7.121100  600.000000  16.533300   130.000000  17.000000
# 75%    1972.000000   7.495000  697.000000  17.066700   187.000000  23.000000
# max    1978.000000   8.493700  830.000000  17.650000   292.000000  31.000000
#
#           FrancePop
# count     25.000000
# mean   49694.436760
# std     3665.270243
# min    43183.569000
# 25%    46583.995000
# 50%    50254.966000
# 75%    52894.183000
# max    54602.193000

# %%
dataset.plot(x='AGST', y='Price', style='o')
plt.title('AGST vs Price')
plt.xlabel('AGST')
plt.ylabel('Price')

# x --> y
# y = mX1 + C
# price = theta1*AGST+ theta0
# Out:
# Text(0, 0.5, 'Price')

# %%
dataset.plot(x='WinterRain', y='Price', style='o')
plt.title('WinterRain vs Price')
plt.xlabel('WinterRain')
plt.ylabel('Price')

# here from plot we cant see the linear regression between winter and price so cant consider this for further
# Out:
# Text(0, 0.5, 'Price')

# %%
dataset.plot(x='Age', y='Price', style='o')
plt.title('Age vs Price')
plt.xlabel('Age')
plt.ylabel('Price')

# this is not apparently better than AGST
# Out:
# Text(0, 0.5, 'Price')

# %%
dataset.plot(x='FrancePop', y='Price', style='o')
plt.title('FrancePop vs Price')
plt.xlabel('FrancePop')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# M2
# $
# Price = \theta_0 + \theta_1 *AGST + \theta_2 * Age
# $

# %% [markdown]
# M3
# $
# Price = \theta_0 + \theta_1 *AGST + \theta_2 * Age + \theta_3 * WinterRange
# $

# %% [markdown]
# if we have so many number of attribute our model will be complecated and overfit

# %% [markdown]
# $
# Price =  \theta_0 + AGST* \theta_1
# $

# %%
x = dataset['AGST'].values

# %%
x
# Out:
# array([17.1167, 16.7333, 17.15  , 16.1333, 16.4167, 17.4833, 16.4167,
#        17.3333, 16.3   , 15.7167, 17.2667, 15.3667, 16.5333, 16.2333,
#        16.2   , 16.55  , 16.6667, 16.7667, 14.9833, 17.0667, 16.3   ,
#        16.95  , 17.65  , 15.5833, 15.8167])

# %%
x = dataset['AGST'].values.reshape(-1,1)  # to get in one dimensional value
x
# Out:
# array([[17.1167],
#        [16.7333],
#        [17.15  ],
#        [16.1333],
#        [16.4167],
#        [17.4833],
#        [16.4167],
#        [17.3333],
#        [16.3   ],
#        [15.7167],
#        [17.2667],
#        [15.3667],
#        [16.5333],
#        [16.2333],
#        [16.2   ],
#        [16.55  ],
#        [16.6667],
#        [16.7667],
#        [14.9833],
#        [17.0667],
#        [16.3   ],
#        [16.95  ],
#        [17.65  ],
#        [15.5833],
#        [15.8167]])

# %%
y = dataset['Price'].values.reshape(-1,1)

# %%
y
# Out:
# array([[7.495 ],
#        [8.0393],
#        [7.6858],
#        [6.9845],
#        [6.7772],
#        [8.0757],
#        [6.5188],
#        [8.4937],
#        [7.388 ],
#        [6.7127],
#        [7.3094],
#        [6.2518],
#        [7.7443],
#        [6.8398],
#        [6.2435],
#        [6.3459],
#        [7.5883],
#        [7.1934],
#        [6.2049],
#        [6.6367],
#        [6.2941],
#        [7.292 ],
#        [7.1211],
#        [6.2587],
#        [7.186 ]])

# %%
y.shape
# Out:
# (25, 1)

# %%
model1 = LinearRegression()

# %%
# to find value of theta 0 and 1
model1.fit(x,y)
# Out:
# LinearRegression()

# %%
model1.intercept_  # value of theta 0
# Out:
# array([-3.41776131])

# %%
model1.coef_  # theta 1
# Out:
# array([[0.63509431]])

# %%
-3.41776131 + 0.63509431 * 17.1167
# Out:
# 7.452957465977002

# %%
7.4950 - 7.452957465977002
# Out:
# 0.042042534022997735

# %%
df = pd.DataFrame({'AGST': x.flatten(), 'Actual Price': y.flatten(), 'predicted Price':y_prid.flatten()})  # flatten is to organize this value in column wise

# %%
df
# Out:
#        AGST  Actual Price  predicted Price
# 0   17.1167        7.4950         7.452957
# 1   16.7333        8.0393         7.209462
# 2   17.1500        7.6858         7.474106
# 3   16.1333        6.9845         6.828406
# 4   16.4167        6.7772         7.008391
# 5   17.4833        8.0757         7.685783
# 6   16.4167        6.5188         7.008391
# 7   17.3333        8.4937         7.590519
# 8   16.3000        7.3880         6.934276
# 9   15.7167        6.7127         6.563825
# 10  17.2667        7.3094         7.548222
# 11  15.3667        6.2518         6.341542
# 12  16.5333        7.7443         7.082443
# 13  16.2333        6.8398         6.891915
# 14  16.2000        6.2435         6.870766
# 15  16.5500        6.3459         7.093049
# 16  16.6667        7.5883         7.167165
# 17  16.7667        7.1934         7.230674
# 18  14.9833        6.2049         6.098047
# 19  17.0667        6.6367         7.421203
# 20  16.3000        6.2941         6.934276
# ...

# %%
y_prid = model1.predict(x)

# %%
y_prid
# Out:
# array([[7.45295742],
#        [7.20946226],
#        [7.47410606],
#        [6.82840568],
#        [7.0083914 ],
#        [7.68578299],
#        [7.0083914 ],
#        [7.59051885],
#        [6.9342759 ],
#        [6.56382539],
#        [7.54822157],
#        [6.34154238],
#        [7.0824434 ],
#        [6.89191511],
#        [6.87076647],
#        [7.09304947],
#        [7.16716498],
#        [7.23067441],
#        [6.09804722],
#        [7.4212027 ],
#        [6.9342759 ],
#        [7.3470872 ],
#        [7.79165321],
#        [6.47910381],
#        [6.62733482]])

# %%
df['Residual']=df['Actual Price']-df['predicted Price']

# %%
df  # +ve value are above actual value and -ve shows value are below actual value
# Out:
#        AGST  Actual Price  predicted Price  Residual
# 0   17.1167        7.4950         7.452957  0.042043
# 1   16.7333        8.0393         7.209462  0.829838
# 2   17.1500        7.6858         7.474106  0.211694
# 3   16.1333        6.9845         6.828406  0.156094
# 4   16.4167        6.7772         7.008391 -0.231191
# 5   17.4833        8.0757         7.685783  0.389917
# 6   16.4167        6.5188         7.008391 -0.489591
# 7   17.3333        8.4937         7.590519  0.903181
# 8   16.3000        7.3880         6.934276  0.453724
# 9   15.7167        6.7127         6.563825  0.148875
# 10  17.2667        7.3094         7.548222 -0.238822
# 11  15.3667        6.2518         6.341542 -0.089742
# 12  16.5333        7.7443         7.082443  0.661857
# 13  16.2333        6.8398         6.891915 -0.052115
# 14  16.2000        6.2435         6.870766 -0.627266
# 15  16.5500        6.3459         7.093049 -0.747149
# 16  16.6667        7.5883         7.167165  0.421135
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# sse = sumation of(Sctual - predicted)

# %%
df['Residual^2']=df['Residual']**2

# %%
df
# Out:
#        AGST  Actual Price  predicted Price  Residual  Residual^2
# 0   17.1167        7.4950         7.452957  0.042043    0.001768
# 1   16.7333        8.0393         7.209462  0.829838    0.688631
# 2   17.1500        7.6858         7.474106  0.211694    0.044814
# 3   16.1333        6.9845         6.828406  0.156094    0.024365
# 4   16.4167        6.7772         7.008391 -0.231191    0.053449
# 5   17.4833        8.0757         7.685783  0.389917    0.152035
# 6   16.4167        6.5188         7.008391 -0.489591    0.239700
# 7   17.3333        8.4937         7.590519  0.903181    0.815736
# 8   16.3000        7.3880         6.934276  0.453724    0.205866
# 9   15.7167        6.7127         6.563825  0.148875    0.022164
# 10  17.2667        7.3094         7.548222 -0.238822    0.057036
# 11  15.3667        6.2518         6.341542 -0.089742    0.008054
# 12  16.5333        7.7443         7.082443  0.661857    0.438054
# ...

# %%
SSE = df['Residual^2'].sum()

# %%
print("SSE of model1 is : ",SSE)
# Out:
# SSE of model1 is :  5.734875147020114

# %%
SSE/25
# Out:
# 0.22939500588080455

# %%
MSE = metrics.mean_squared_error(y_prid,y)

# %%
MSE
# Out:
# 0.22939500588080455

# %%
plt.scatter(x,y, color='blue')
plt.plot(x, y_prid, color='red', linewidth=2)
plt.legend(['actual','predicted'],loc='upper left')

# %% [markdown]
# $
# Price = \theta_0 + \theta_1 * AGST + \theta_2 * Harvest Rain
# $

# %%
dataset.head()
# Out:
#    Year   Price  WinterRain     AGST  HarvestRain  Age  FrancePop
# 0  1952  7.4950         600  17.1167          160   31  43183.569
# 1  1953  8.0393         690  16.7333           80   30  43495.030
# 2  1955  7.6858         502  17.1500          130   28  44217.857
# 3  1957  6.9845         420  16.1333          110   26  45152.252
# 4  1958  6.7772         582  16.4167          187   25  45653.805

# %%
x=dataset[['AGST','HarvestRain']]
y=dataset['Price'].values.reshape(-1,1)

# %%
x
# Out:
#        AGST  HarvestRain
# 0   17.1167          160
# 1   16.7333           80
# 2   17.1500          130
# 3   16.1333          110
# 4   16.4167          187
# 5   17.4833          187
# 6   16.4167          290
# 7   17.3333           38
# 8   16.3000           52
# 9   15.7167          155
# 10  17.2667           96
# 11  15.3667          267
# 12  16.5333           86
# 13  16.2333          118
# 14  16.2000          292
# 15  16.5500          244
# 16  16.6667           89
# 17  16.7667          112
# 18  14.9833          158
# 19  17.0667          123
# 20  16.3000          184
# 21  16.9500          171
# 22  17.6500          247
# 23  15.5833           87
# 24  15.8167           51

# %%
y
# Out:
# array([[7.495 ],
#        [8.0393],
#        [7.6858],
#        [6.9845],
#        [6.7772],
#        [8.0757],
#        [6.5188],
#        [8.4937],
#        [7.388 ],
#        [6.7127],
#        [7.3094],
#        [6.2518],
#        [7.7443],
#        [6.8398],
#        [6.2435],
#        [6.3459],
#        [7.5883],
#        [7.1934],
#        [6.2049],
#        [6.6367],
#        [6.2941],
#        [7.292 ],
#        [7.1211],
#        [6.2587],
#        [7.186 ]])

# %%
model2 = LinearRegression()
model2.fit(x,y)
# Out:
# LinearRegression()

# %%
model2.intercept_
# Out:
# array([-2.2026536])

# %%
model2.coef_
# Out:
# array([[ 0.60261691, -0.00457006]])

# %%
y_pred = model2.predict(x)

# %%
df = pd.DataFrame({'AGST':x['AGST'],
                   'HarvestRain':x['HarvestRain'],
                  'Actual Price':y.flatten(),
                  'Predicted Price':y_pred.flatten()})

# %%
df
# Out:
#        AGST  HarvestRain  Actual Price  Predicted Price
# 0   17.1167          160        7.4950         7.380950
# 1   16.7333           80        8.0393         7.515511
# 2   17.1500          130        7.6858         7.538119
# 3   16.1333          110        6.9845         7.016840
# 4   16.4167          187        6.7772         6.835727
# 5   17.4833          187        8.0757         7.478478
# 6   16.4167          290        6.5188         6.365011
# 7   17.3333           38        8.4937         8.069024
# 8   16.3000           52        7.3880         7.382359
# 9   15.7167          155        6.7127         6.560137
# 10  17.2667           96        7.3094         7.763826
# 11  15.3667          267        6.2518         5.837375
# 12  16.5333           86        7.7443         7.367568
# 13  16.2333          118        6.8398         7.040541
# 14  16.2000          292        6.2435         6.225284
# 15  16.5500          244        6.3459         6.655563
# ...

# %%
MSE2 =  metrics.mean_squared_error(y_pred, y)

# %%
MSE2
# Out:
# 0.11881493360694172

# %%
MSE
# Out:
# 0.22939500588080455

# %% [markdown]
# mean square error (MSE) of model 2 is lesss than model 1

# %%
Eval = pd.DataFrame({'Model1':[MSE],'Model2':[MSE2]})
Eval.index=['MSE']

# %%
from matplotlib.ticker import MaxNLocator

# %%
# %matplotlib   
#For showing in seperate window
Xs = dataset['AGST'].values
Ys = dataset['HarvestRain'].values
Zs = dataset['Price'].values
# Out:
# Using matplotlib backend: <object object at 0x000001420BF02260>

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# %%
ax.scatter(Xs, Ys, Zs, color='r', label='Actual')
ax.scatter(Xs, Ys, y_pred.reshape(Zs.shape), color='g', label='Predicted')
surf = ax.plot_trisurf(Xs, Ys, y_pred.reshape(Zs.shape), linewidth=0)

# %%
ax.set_xlabel('AGST')
ax.set_ylabel('HarvestRain')
ax.set_zlabel('Price')
# Out:
# Text(0.5, 0, 'Price')

# %%
ax.legend()

# %%
ax.xaxis.set_major_locator(MaxNLocator(5))
ax.yaxis.set_major_locator(MaxNLocator(6))
ax.zaxis.set_major_locator(MaxNLocator(5))

# %%
fig.tight_layout()

# %%
plt.show()

# %% [markdown]
# $
# Price = \theta_0 + \theta_1 * AGST + \theta_2 * HarvestRain + \theta_3 * WinterRain + \theta_4 * Age + \theta_5 * FrancePop
# $

# %%
dataset.columns
# Out:
# Index(['Year', 'Price', 'WinterRain', 'AGST', 'HarvestRain', 'Age',
#        'FrancePop'],
#       dtype='object')

# %%
x = dataset[['AGST','HarvestRain','Age','FrancePop','WinterRain']]

# %%
x
# Out:
#        AGST  HarvestRain  Age  FrancePop  WinterRain
# 0   17.1167          160   31  43183.569         600
# 1   16.7333           80   30  43495.030         690
# 2   17.1500          130   28  44217.857         502
# 3   16.1333          110   26  45152.252         420
# 4   16.4167          187   25  45653.805         582
# 5   17.4833          187   24  46128.638         485
# 6   16.4167          290   23  46583.995         763
# 7   17.3333           38   22  47128.005         830
# 8   16.3000           52   21  48088.673         697
# 9   15.7167          155   20  48798.990         608
# 10  17.2667           96   19  49356.943         402
# 11  15.3667          267   18  49801.821         602
# 12  16.5333           86   17  50254.966         819
# 13  16.2333          118   16  50650.406         714
# 14  16.2000          292   15  51034.413         610
# 15  16.5500          244   14  51470.276         575
# 16  16.6667           89   13  51918.389         622
# ...

# %%
y=dataset['Price'].values.reshape(-1,1)

# %%
model3 = LinearRegression()
model3.fit(x,y)
# Out:
# LinearRegression()

# %%
model3.intercept_
# Out:
# array([-0.45039886])

# %%
model3.coef_
# Out:
# array([[ 6.01223884e-01, -3.95812450e-03,  5.84748489e-04,
#         -4.95273038e-05,  1.04250681e-03]])

# %%
y_predict = model3.predict(x)

# %%
MSE3 = metrics.mean_squared_error(y_pred, y)

# %%
MSE3
# Out:
# 0.11881493360694172

# %%
MSE2
# Out:
# 0.11881493360694172

# %%
MSE
# Out:
# 0.22939500588080455

# %%
Eval['Model3']=MSE3

# %%
MSE3
# Out:
# 0.11881493360694172

# %%
# %matplotlib inline
dataset.plot(x='Age',y='FrancePop',style='o')
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# $
# Price = \theta_0 + \theta_1 * AGST + \theta_2 * HarvestRain + \theta_3 * WinterRain + \theta_4 * Age
# $

# %%
x = dataset[['AGST','HarvestRain','Age','WinterRain']]

# %%
y = dataset['Price'].values.reshape(-1,1)

# %%
model4 = LinearRegression()
model4.fit(x,y)
# Out:
# LinearRegression()

# %%
model4.intercept_
# Out:
# array([-3.42998019])

# %%
model4.coef_
# Out:
# array([[ 0.60720935, -0.00397153,  0.02393083,  0.00107551]])

# %%
y_pred = model4.predict(x)

# %%
y_pred
# Out:
# array([[7.71515356],
#        [7.87293687],
#        [7.67732765],
#        [7.00335549],
#        [7.01993151],
#        [7.53932616],
#        [6.75766829],
#        [8.363191  ],
#        [7.51318707],
#        [6.63028304],
#        [7.56029312],
#        [5.91863325],
#        [7.55530516],
#        [7.10919438],
#        [6.26214399],
#        [6.60372738],
#        [7.31679442],
#        [7.18587836],
#        [5.88022723],
#        [7.0882792 ],
#        [6.56948742],
#        [6.9897216 ],
#        [6.9233729 ],
#        [6.71339661],
#        [6.91178436]])

# %%
MSE4=metrics.mean_absolute_error(y_pred,y)

# %%
MSE4
# Out:
# 0.22593744084778286

# %%
Eval['Model4']=MSE4

# %%
Eval
# Out:
#        Model1    Model2    Model3    Model4
# MSE  0.229395  0.118815  0.118815  0.225937

# %% [markdown]
# # Regression model

# %% [markdown]
# ![image.png](attachment:image.png)
